# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv.imread('/content/sunlight.png')

blur = cv.blur(img,(5,5))
plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(blur), plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
blur = cv.blur(img, (5, 5), 0)
plt.figure(figsize=(5, 5))
# Instead of 'show(blur)', use 'plt.imshow(blur)' to display the image
plt.imshow(blur)
plt.show() # Add plt.show() to actually display the plot

# %%
from PIL import Image
from google.colab.patches import cv2_imshow

# %%
pip install sewar
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sewar: filename=sewar-0.4.6-py3-none-any.whl size=11421 sha256=2ea0ea569d8f9bcf730aa4748c3624f7ff7ac62cc83bd965dbfe1d54a278a78c
#   Stored in directory: /root/.cache/pip/wheels/87/f9/d9/6ec7e7b470df5ba0e317c6988ba7677a124ab220f5effea702
# Successfully built sewar
# ...

# %%
from sewar import full_ref
from skimage import measure, metrics

# %%
gaussian_kernel = np.ones((3,3), np.float32)/25
conv_gaussian = cv.filter2D(blur, -1, gaussian_kernel, borderType = cv.BORDER_CONSTANT)

plt.figure(figsize=(5, 5))
plt.imshow(blur)
plt.show() # Add plt.show() to actually display the plot

# %%
# Save the blurred image
cv.imwrite('blurred_image.jpg', blur)
# Save the Gaussian filtered image
cv.imwrite('gaussian_filtered_image.jpg', conv_gaussian)
# Out:
# True

# %%
orig = cv.imread('blurred_image.jpg',1)
gaussian = cv.imread('gaussian_filtered_image.jpg',1)

# %%
rmse_skimg = metrics.normalized_root_mse(orig, gaussian)
print("RMSE: based on scikit-image = ", rmse_skimg)

mse_skimg = metrics.mean_squared_error(orig, gaussian)
print("MSE: based on scikit-image = ", mse_skimg)

psnr_skimg = metrics.peak_signal_noise_ratio(orig, gaussian, data_range=None)
print("PSNR: based on scikit-image = ", psnr_skimg)

ssim_skimg = ssim(orig, gaussian, data_range=img.max() - img.min(), multichannel=True, win_size=win_size, channel_axis=2)
print("SSIM: based on scikit-image = ", ssim_skimg)
# Out:
# RMSE: based on scikit-image =  0.6416992454791616
# MSE: based on scikit-image =  7600.36335745165
# PSNR: based on scikit-image =  9.322460053813286
# SSIM: based on scikit-image =  0.561958567046697
